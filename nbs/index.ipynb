# %%
#| hide
from automated_testing.core import *

# %% [markdown]
# # automated-testing
#
# > Notes on automated testing

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install automated_testing in Development mode

# %% [markdown]
# ```sh
# # make sure automated_testing package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to automated_testing
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/jit3pam/automated-testing.git
# ```
#
# or from [conda][conda][**TODO**]
#
# ```sh
# $ conda install -c jit3pam automated_testing
# ```
#
# or from [pypi][pypi][**TODO**]
#
#
# ```sh
# $ pip install automated_testing
# ```
#
#
# [repo]: https://github.com/jit3pam/automated-testing
# [docs]: https://jit3pam.github.io/automated-testing/
# [pypi]: https://pypi.org/project/automated-testing/
# [conda]: https://anaconda.org/jit3pam/automated-testing

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/jit3pam/automated-testing
# [docs]: https://jit3pam.github.io/automated-testing/
# [pypi]: https://pypi.org/project/automated-testing/
# [conda]: https://anaconda.org/jit3pam/automated-testing

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
